# %% [markdown]
# # Project 1: Data Analysis of the Data Set "Honeypot_Sample_Log.csv"

# %% [markdown]
# #### Student Name: Isaac Kone
# #### Student ID: 501280479

# %% [markdown]
# ## Introduction:
#
# In the realm of cybersecurity, computer programming and scripting play an indispensable role. You might be pondering, "How are programming/scripting and data science intertwined with the discipline of cybersecurity?" Cybersecurity isn't just about adhering to procedures, implementing policies, updating software, or merely assisting users with password issues.
#
# In the vast field of cybersecurity, there exist numerous roles, each demanding a distinct set of skills. Although it isn't imperative for all cybersecurity roles to possess programming and scripting expertise, such skills are undeniably beneficial. For novices in the field, many entry-level cybersecurity roles might not mandate coding proficiency, however, as you ascend the career ladder, you'll discover that programming and scripting become increasingly crucial. Especially, if you find yourself in roles such as a Cyber Security Analyst or a Digital Forensics expert, where interfacing with logs, or even logs from a Security Incident Event Management (SIEM) system, becomes inevitable
#
# ### The Functionality of SIEM
#
# SIEM software is designed to aggregate log and event data from various sources, be it applications, devices, networks, infrastructure, or systems, thereby facilitating a comprehensive analysis and offering a panoramic view of an organization's IT landscape. Though SIEMs are equipped with standard reporting tools, there might arise situations necessitating the creation of bespoke reports or specific actions. Herein lies the significance of programming/scripting. A majority of SIEM platforms are compatible with programming languages such as Python, Perl, or Bash, enabling users to craft custom reports and execute tailored actions.
#
# ### Introduction to the Honeynet Project
#
# This project serves as a practical introduction to cybersecurity through the lens of honeynets. A honeynet is essentially a mock network, equipped with multiple honeypots. These honeypots, while mimicking genuine networks, are set up on one or several servers, each epitomizing a distinct environment.
#
# Primarily, honeypots are positioned outside the shielded network to intercept external threats. The honeypots in this specific project were configured to permit communication from both the network's periphery and its internal sections. It's pertinent to note that many contemporary cyber-attacks originate internally, often stemming from seemingly innocuous activities like clicking an email link. When internal IP addresses interact with honeypots, it's an alarming indication of potential network compromise. However, for safety reasons, any such internal attacks have been excised from the provided dataset. Additionally, you will not have access to any malware submitted for examination.

# %% [markdown]
# ## Objective:
# Create graphs to derive comprehensive insights on security threats by visualizing key metrics from the dataset.
#
#  - <b>Top 10 Threat Actors Categorized by IP Address:</b> A representation that highlights the most frequent IP addresses that are potential threat actors.
#
#  - <b>Top 10 Destination Ports Including Their Descriptive Names:</b> This graph will provide a visualization of the most commonly targeted destination ports, accompanied by their respective official or commonly known names.
#
#  - <b>Top 10 Communication Protocols (Excluding Services):</b> Present a chart detailing the primary communication protocols in use, explicitly omitting any associated services.
#
#  - <b>Top 10 Ports Under Attack:</b> Visualize the ports that experience the highest number of unauthorized access attempts.
#
# For each of the above, explain how is this information important, who would use it, and how will it be or should be used?
#
# **Do not use Pie Charts or Ring/Doughnut Charts for your graphs. Unless you wish to reduce your grade.**

# %% [markdown]
# ### Project 1 due on July 11, 2025 (18:00)

# %% [markdown]
# ### Start Program Code Here

# %% [markdown]
# #### Libraries used

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from IPython.display import display
from tqdm import tqdm

# %% [markdown]
# #### Set Data Paths:

# %%
# Set paths
main_dir = 'D:/'
data_dir = main_dir +'Python Data/'
output_dir = main_dir +'Reports/'

# Set working directory
os.chdir(main_dir)

# Remove annoying error
pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5 data_dir = './'
#       8 # Set working directory
# ----> 9 os.chdir(main_dir)
#      11 # Remove annoying error
#      12 pd.options.mode.chained_assignment = None  # default='warn'
#
# NameError: name 'os' is not defined

# %% [markdown]
# #### Functions:

# %%
def topten_threat_actors(data: pd.DataFrame):
    display("Generating Graph 1: Top 10 Threat Actors by IP Address...")
    top_10_ips = data.groupby('source_ip').size().nlargest(10)

    plt.figure(figsize=(12, 6))
    top_10_ips.plot(kind='bar', color='skyblue')
    plt.title('Top 10 Threat Actors by IP Address', fontsize=16)
    plt.xlabel('Source IP Address', fontsize=12)
    plt.ylabel('Number of Attacks', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'top_10_threat_actors.png'))
    plt.close() # Close the plot to free up memory

    
# Graph 2: Top 10 Destination Ports with Descriptive Names
def topten_dest_port(data: pd.DataFrame):
    display("Generating Graph 2: Top 10 Targeted Destination Ports...")
    top_10_ports = data.groupby('destination_port').size().nlargest(10)

    port_names = {
        '21': 'FTP', '22': 'SSH', '23': 'Telnet', '25': 'SMTP', '53': 'DNS',
        '80': 'HTTP', '110': 'POP3', '143': 'IMAP', '443': 'HTTPS', '445': 'SMB',
        '3306': 'MySQL', '3389': 'RDP', '5900': 'VNC', '8080': 'HTTP Proxy'
    }
    port_labels = [f"{port} ({port_names.get(port, 'Unknown')})" for port in top_10_ports.index]

    plt.figure(figsize=(12, 8))
    top_10_ports.plot(kind='barh', color='coral')
    plt.title('Top 10 Targeted Destination Ports', fontsize=16)
    plt.xlabel('Number of Attacks', fontsize=12)
    plt.ylabel('Destination Port', fontsize=12)
    plt.yticks(range(len(port_labels)), port_labels)
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'top_10_destination_ports.png'))
    plt.close()

# Graph 3: Top 10 Communication Protocols
def topten_protocol(data: pd.DataFrame):
    display("Generating Graph 3: Top 10 Communication Protocols...")
    top_10_protocols = data.groupby('protocol').size().nlargest(10)
    plt.figure(figsize=(12, 6))
    top_10_protocols.plot(kind='bar', color='lightgreen')
    plt.title('Top 10 Communication Protocols Used in Attacks', fontsize=16)
    plt.xlabel('Protocol', fontsize=12)
    plt.ylabel('Number of Occurrences', fontsize=12)
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'top_10_protocols.png'))
    plt.close()

# Graph 4: Top 10 Ports Under Attack
def topten_portatk(data: pd.DataFrame):
    display("Generating Graph 4: Top 10 Ports Under Attack...")
    top_10_ports_attacked = data.groupby('destination_port').size().nlargest(10)
    plt.figure(figsize=(12, 6))
    top_10_ports_attacked.plot(kind='bar', color='gold')
    plt.title('Top 10 Ports Under Attack', fontsize=16)
    plt.xlabel('Destination Port Number', fontsize=12)
    plt.ylabel('Number of Attacks', fontsize=12)
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, 'top_10_ports_attacked.png'))
    plt.close()

# %% [markdown]
# #### Load Data:

# %%
def load_csv_with_progress(path: str, chunksize: int = 100_000) -> pd.DataFrame:
    """Reads a large TSV file in chunks with progress and returns a cleaned DataFrame."""
    display(f"[+] Reading CSV in chunks from: {path}")
    chunks = []
    total_lines = sum(1 for _ in open(path, 'r', encoding='utf8'))
    with tqdm(total=total_lines, desc="Loading CSV") as pbar:
        for chunk in pd.read_csv(path, sep='\t', encoding='utf8', dtype='string', chunksize=chunksize):
            chunks.append(chunk)
            pbar.update(len(chunk))
    df = pd.concat(chunks, ignore_index=True)
    df = df[:-1]
    display(f"[+] Finished reading CSV. Total rows: {len(df)}")
    return df

# %%
if __name__ == "__main__":
    df = load_csv_with_progress(data_dir + "Honeypot_Sample_Log.csv")
    topten_dest_port(df)
    topten_protocol(df)
    topten_threat_actors(df)
    topten_portatk(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 if __name__ == "__main__":
# ----> 2     df = load_csv_with_progress(data_dir + "Honeypot_Sample_Log.csv")
#       3     topten_dest_port(df)
#       4     topten_protocol(df)
#
# NameError: name 'load_csv_with_progress' is not defined

# %% [markdown]
# ## Observations, Analysis, and Conclusions

# %%
The first graph shows port 80 (HTTP) as the most targeted, with nearly one million attacks, followed by port 5060 (SIP) and port 22 (SSH). These reflect a focus on exploiting web services and remote management tools. Other notable ports like 3389 (RDP) and 3306 (MySQL) suggest interest in remote access and databases.

# %%
The second chart reinforces these findings, with ports 80, 5060, and 22 dominating. Ports 443 (HTTPS) and 8080 (HTTP Proxy) also appear, showing attackers probe both encrypted services and proxies.

# %%
The third graph on protocols confirms HTTP as the most exploited, followed by pcap, SIP, and SSH. MySQLd and HTTPS appear lower but show attackers also target databases and encrypted connections.

# %%
The last graph shows a handful of IPs, like 185.156.177.108 and 188.165.222.17, launching tens of thousands of attacks each, likely automated campaigns. This suggests the need for blocking high-volume sources and securing exposed services.
